# %%
from polygraphpy.utils.get_vdw_volume import get_vdw_volume

get_vdw_volume(verbose=True)
# Out:
# SMILES                                             | VDW Volume (Å³)
# ----------------------------------------------------------------------
# CCO                                                |           47.86
# c1ccccc1                                           |           88.83
# O=C1CCCCCCCCCCC1                                   |          192.80
# C1CCCC1                                            |           80.47
# CC(=O)c1ccc(C)cc1                                  |          139.18
# O=C2c1ccccc1C(=O)c3ccccc23                         |          192.31
# O=P(c1ccccc1)(c2ccccc2)c3ccccc3                    |          270.84
# CN1CCCC1c2cccnc2                                   |          164.90
# CCOC(=O)C1(CCN(C)CC1)c2ccccc2                      |          243.24
# Cc1cc(=O)n(c2ccccc2)n1C                            |          182.08
# CN(C)P(N(C)C)N(C)C                                 |          160.62
# CCC(=O)C(CC(C)N(C)C)(c1ccccc1)c2ccccc2             |          320.18
# ...
